# %% [markdown]
# # Demo Reading In Atlas Files and Electrode Localized Files

# %%
import sys, os
import pandas as pd
import numpy as np

from pprint import pprint
import nibabel as nb

sys.path.append('../../')
sys.path.append('../../../../')

from eztrack.edp.utils.utils import writejsonfile, loadjsonfile, MatReader
from eztrack.pipeline.utils.utils import load_results_data

# %%
reference = 'monopolar'
modality = 'ieeg'
center = 'umf'
patid = 'umf001'
datasetid = 'sz'

atlasname = 'dk'

results_dir = f"/Users/adam2392/Downloads/output_new/fragility/{reference}/{modality}/{center}"
outputmetafilepath = os.path.join(results_dir, f"{patid}_{datasetid}_frag.json")

atlasmapfile = "../../data/mrtrix3_labelconvert/fs2lobes_cinginc_convert.txt"
atlaslabelfile = "../../data/mrtrix3_labelconvert/fs2lobes_cinginc_labels.txt"

chlabelfile = f"/Users/adam2392/Dropbox/phd_research/data/neuroimaging_results/freesurfer_output/{patid}/elecs/{patid}_elecs_all_{atlasname}.mat"

# %%
# load in the data
model = load_results_data(results_dir, outputmetafilepath, datatype='frag')

patient_id = model.patient_id

# merge data
metadata = model.get_metadata()
pat_id = metadata['patient_id']
dataset_id = metadata['dataset_id'].replace("_", '')
modality = metadata['modality']

print("looking at: ", pat_id, dataset_id, modality)
print(metadata.keys())
# Out:
# Loading results data from:  /Users/adam2392/Downloads/output_new/fragility/monopolar/ieeg/umf/umf001_sz_fragmodel.npz
# looking at:  umf001 sz ieeg
# dict_keys(['ablated_contacts', 'age_surgery', 'bad_channels', 'bad_contacts', 'chanlabels', 'channeltypes', 'clinical_center', 'clinical_difficulty', 'clinical_match', 'clinical_semiology', 'dataset_id', 'date_of_recording', 'edffilename', 'engel_score', 'equipment', 'events', 'ez_elecs', 'ez_hypo_brainregion', 'ez_hypo_contacts', 'filename', 'gender', 'hand_dominant', 'highpass_freq', 'length_of_recording', 'linefreq', 'lowpass_freq', 'modality', 'non_eeg_channels', 'note', 'number_chans', 'numwins', 'offsetind', 'offsetsec', 'onset', 'onset_age', 'onsetind', 'onsetsec', 'outcome', 'patient_id', 'perturbtype', 'radius', 'reference', 'resect_elecs', 'resected_contacts', 'resultfilename', 'samplepoints', 'samplerate', 'seizure_semiology', 'stabilizeflag', 'stepsize', 'termination', 'type', 'winsize', 'onsetwin', 'offsetwin'])

# %%
def build_fs_atlas_map(atlasint_path, atlaslabel_path):
    """
    Build's freesurfer label name mapping from atlas names to their lobe values.
    """
    lut = {}
    with open(atlasint_path, 'r') as fd:
        # read in path line by line
        for line in fd.readlines():
            # skip comment lines
            if not line[0] == '#' and line.strip():
                val, name = line.strip().split()
                lut[name] = int(val)
                
    lut2 = {}
    with open(atlaslabel_path, 'r') as fd:
        # read in path line by line
        for line in fd.readlines():
            # skip comment lines
            if not line[0] == '#' and line.strip():
                val, name = line.strip().split()
                lut2[int(val)] = name

    masterlut = {}
    for region in lut.keys():
        masterlut[region] = lut2[lut[region]]
        
    return masterlut

# %%
# creates a dictionary between atlas regions and lobes
atlas_to_lobe = build_fs_atlas_map(atlasmapfile, atlaslabelfile)
display(atlas_to_lobe)
# Out:
# {'Unknown': 'Unknown',
#  'ctx-lh-bankssts': 'L_Temporal_lobe',
#  'ctx-lh-caudalanteriorcingulate': 'L_Frontal_lobe',
#  'ctx-lh-caudalmiddlefrontal': 'L_Frontal_lobe',
#  'ctx-lh-cuneus': 'L_Occipital_lobe',
#  'ctx-lh-entorhinal': 'L_Temporal_lobe',
#  'ctx-lh-fusiform': 'L_Temporal_lobe',
#  'ctx-lh-inferiorparietal': 'L_Parietal_lobe',
#  'ctx-lh-inferiortemporal': 'L_Temporal_lobe',
#  'ctx-lh-isthmuscingulate': 'L_Parietal_lobe',
#  'ctx-lh-lateraloccipital': 'L_Occipital_lobe',
#  'ctx-lh-lateralorbitofrontal': 'L_Frontal_lobe',
#  'ctx-lh-lingual': 'L_Occipital_lobe',
#  'ctx-lh-medialorbitofrontal': 'L_Frontal_lobe',
#  'ctx-lh-middletemporal': 'L_Temporal_lobe',
#  'ctx-lh-parahippocampal': 'L_Temporal_lobe',
#  'ctx-lh-paracentral': 'L_Frontal_lobe',
#  'ctx-lh-parsopercularis': 'L_Frontal_lobe',
#  'ctx-lh-parsorbitalis': 'L_Frontal_lobe',
#  'ctx-lh-parstriangularis': 'L_Frontal_lobe',
#  'ctx-lh-pericalcarine': 'L_Occipital_lobe',
#  'ctx-lh-postcentral': 'L_Parietal_lobe',
#  'ctx-lh-posteriorcingulate': 'L_Parietal_lobe',
#  'ctx-lh-precentral': 'L_Frontal_lobe',
#  'ctx-lh-precuneus': 'L_Parietal_lobe',
#  'ctx-lh-rostralanteriorcingulate': 'L_Frontal_lobe',
#  'ctx-lh-rostralmiddlefrontal': 'L_Frontal_lobe',
#  'ctx-lh-superiorfrontal': 'L_Frontal_lobe',
#  'ctx-lh-superiorparietal': 'L_Parietal_lobe',
#  'ctx-lh-superiortemporal': 'L_Temporal_lobe',
#  'ctx-lh-supramarginal': 'L_Parietal_lobe',
#  'ctx-lh-frontalpole': 'L_Frontal_lobe',
#  'ctx-lh-temporalpole': 'L_Temporal_lobe',
#  'ctx-lh-transversetemporal': 'L_Temporal_lobe',
#  'Left-Cerebellum-Cortex': 'L_Cerebellum',
#  'Left-Thalamus-Proper': 'L_Subcortical',
#  'Left-Caudate': 'L_Subcortical',
#  'Left-Putamen': 'L_Subcortical',
#  'Left-Pallidum': 'L_Subcortical',
#  'Left-Hippocampus': 'L_Subcortical',
#  'Left-Amygdala': 'L_Subcortical',
#  'Left-Accumbens-area': 'L_Subcortical',
#  'Right-Thalamus-Proper': 'R_Subcortical',
#  'Right-Caudate': 'R_Subcortical',
#  'Right-Putamen': 'R_Subcortical',
#  'Right-Pallidum': 'R_Subcortical',
#  'Right-Hippocampus': 'R_Subcortical',
#  'Right-Amygdala': 'R_Subcortical',
#  'Right-Accumbens-area': 'R_Subcortical',
#  'Right-Cerebellum-Cortex': 'R_Cerebellum',
#  'ctx-rh-bankssts': 'R_Temporal_lobe',
#  'ctx-rh-caudalanteriorcingulate': 'R_Frontal_lobe',
#  'ctx-rh-caudalmiddlefrontal': 'R_Frontal_lobe',
#  'ctx-rh-cuneus': 'R_Occipital_lobe',
#  'ctx-rh-entorhinal': 'R_Temporal_lobe',
#  'ctx-rh-fusiform': 'R_Temporal_lobe',
#  'ctx-rh-inferiorparietal': 'R_Parietal_lobe',
#  'ctx-rh-inferiortemporal': 'R_Temporal_lobe',
#  'ctx-rh-isthmuscingulate': 'R_Parietal_lobe',
#  'ctx-rh-lateraloccipital': 'R_Occipital_lobe',
#  'ctx-rh-lateralorbitofrontal': 'R_Frontal_lobe',
#  'ctx-rh-lingual': 'R_Occipital_lobe',
#  'ctx-rh-medialorbitofrontal': 'R_Frontal_lobe',
#  'ctx-rh-middletemporal': 'R_Temporal_lobe',
#  'ctx-rh-parahippocampal': 'R_Temporal_lobe',
#  'ctx-rh-paracentral': 'R_Frontal_lobe',
#  'ctx-rh-parsopercularis': 'R_Frontal_lobe',
#  'ctx-rh-parsorbitalis': 'R_Frontal_lobe',
#  'ctx-rh-parstriangularis': 'R_Frontal_lobe',
#  'ctx-rh-pericalcarine': 'R_Occipital_lobe',
#  'ctx-rh-postcentral': 'R_Parietal_lobe',
#  'ctx-rh-posteriorcingulate': 'R_Parietal_lobe',
#  'ctx-rh-precentral': 'R_Frontal_lobe',
#  'ctx-rh-precuneus': 'R_Parietal_lobe',
#  'ctx-rh-rostralanteriorcingulate': 'R_Frontal_lobe',
#  'ctx-rh-rostralmiddlefrontal': 'R_Frontal_lobe',
#  'ctx-rh-superiorfrontal': 'R_Frontal_lobe',
#  'ctx-rh-superiorparietal': 'R_Parietal_lobe',
#  'ctx-rh-superiortemporal': 'R_Temporal_lobe',
#  'ctx-rh-supramarginal': 'R_Parietal_lobe',
#  'ctx-rh-frontalpole': 'R_Frontal_lobe',
#  'ctx-rh-temporalpole': 'R_Temporal_lobe',
#  'ctx-rh-transversetemporal': 'R_Temporal_lobe'}

# %%
def merge_atlas_mappings(metadata, chlabelfile, atlas_to_lobe_dict, atlasname):
    # define our matlab matfile reader
    matreader = MatReader()
    elecsdict = matreader.loadmat(chlabelfile)

    elecmatrix = elecsdict['elecmatrix']
    eleclabels = elecsdict['eleclabels']
    elecanat = elecsdict['anatomy']
    eleclabels = np.array([x[0] for x in eleclabels])
    elecanat = np.array([x[3] for x in elecanat])

    # add dictionary mapping to each contact
    ch_lobe_mapping = {}
    ch_atlas_mapping = {}
    for idx, ch in enumerate(eleclabels):
        ch_anat = elecanat[idx]

        if any(x in ch_anat for x in ['rh-insula', 'lh-insula']):
            ch_lobe = "Unknown"
        else:
            ch_lobe = atlas_to_lobe[ch_anat]

        ch_lobe_mapping[ch] = ch_lobe
        ch_atlas_mapping[ch] = ch_anat
    
    metadata['ch_lobe_mapping'] = ch_lobe_mapping
    metadata['ch_atlas_mapping'] = ch_atlas_mapping
    metadata['ch_atlas'] = atlasname
    return metadata

# %%
# creates a dictionary between atlas regions and lobes
atlas_to_lobe = build_fs_atlas_map(atlasmapfile, atlaslabelfile)
    
# merge in atlas mappings
metadata = merge_atlas_mappings(metadata, chlabelfile, atlas_to_lobe, atlasname)

# %%
print(metadata.keys())
# Out:
# dict_keys(['ablated_contacts', 'age_surgery', 'bad_channels', 'bad_contacts', 'chanlabels', 'channeltypes', 'clinical_center', 'clinical_difficulty', 'clinical_match', 'clinical_semiology', 'dataset_id', 'date_of_recording', 'edffilename', 'engel_score', 'equipment', 'events', 'ez_elecs', 'ez_hypo_brainregion', 'ez_hypo_contacts', 'filename', 'gender', 'hand_dominant', 'highpass_freq', 'length_of_recording', 'linefreq', 'lowpass_freq', 'modality', 'non_eeg_channels', 'note', 'number_chans', 'numwins', 'offsetind', 'offsetsec', 'onset', 'onset_age', 'onsetind', 'onsetsec', 'outcome', 'patient_id', 'perturbtype', 'radius', 'reference', 'resect_elecs', 'resected_contacts', 'resultfilename', 'samplepoints', 'samplerate', 'seizure_semiology', 'stabilizeflag', 'stepsize', 'termination', 'type', 'winsize', 'onsetwin', 'offsetwin', 'ch_lobe_mapping', 'ch_atlas_mapping', 'ch_atlas'])

# %%
pprint(metadata)
# Out:
# {'ablated_contacts': [],
#  'age_surgery': 32.0,
#  'bad_channels': ['event',
#                   'ekgl',
#                   'ekgr',
#                   'lm',
#                   'c65',
#                   'c66',
#                   'c67',
#                   'c68',
#                   'c69',
#                   'c70',
#                   'c71',
#                   'c72',
#                   'c73',
#                   'c74',
#                   'c75',
#                   'c76',
#                   'c77',
#                   'c78',
#                   'c79',
#                   'c80',
#                   'c81',
#                   'c82',
#                   'c83',
#                   'c84',
#                   'c85',
#                   'c86',
#                   'c87',
#                   'c88',
#                   'c89',
#                   'c90',
#                   'c91',
#                   'c92',
#                   'c93',
#                   'c94',
#                   'c95',
#                   'c96',
#                   'c97',
#                   'c98',
#                   'c99',
#                   'c100',
#                   'c101',
#                   'c102',
#                   'c103',
#                   'c104',
#                   'c105',
#                   'c106',
#                   'c107',
#                   'c108',
#                   'c109',
#                   'c110',
#                   'c111',
#                   'c112',
#                   'c113',
#                   'c114',
#                   'c115',
#                   'c116',
#                   'c117',
#                   'c118',
#                   'c119',
#                   'c120',
#                   'c121',
#                   'c122',
#                   'c123',
#                   'c124',
#                   'c125',
#                   'c126',
#                   'c127',
#                   'c128'],
#  'bad_contacts': ['c65',
#                   'c66',
#                   'c67',
#                   'c68',
#                   'c69',
#                   'c70',
#                   'c71',
#                   'c72',
#                   'c73',
#                   'c74',
#                   'c75',
#                   'c76',
#                   'c77',
#                   'c78',
#                   'c79',
#                   'c80',
#                   'c81',
#                   'c82',
#                   'c83',
#                   'c84',
#                   'c85',
#                   'c86',
#                   'c87',
#                   'c88',
#                   'c89',
#                   'c90',
#                   'c91',
#                   'c92',
#                   'c93',
#                   'c94',
#                   'c95',
#                   'c96',
#                   'c97',
#                   'c98',
#                   'c99',
#                   'c100',
#                   'c101',
#                   'c102',
#                   'c103',
#                   'c104',
#                   'c105',
#                   'c106',
#                   'c107',
#                   'c108',
#                   'c109',
#                   'c110',
#                   'c111',
#                   'c112',
#                   'c113',
#                   'c114',
#                   'c115',
#                   'c116',
#                   'c117',
#                   'c118',
#                   'c119',
#                   'c120',
#                   'c121',
#                   'c122',
#                   'c123',
#                   'c124',
#                   'c125',
#                   'c126',
#                   'c127',
#                   'c128'],
#  'ch_atlas': 'dk',
#  'ch_atlas_mapping': {'btm1': 'ctx-rh-fusiform',
#                       'btm2': 'ctx-rh-fusiform',
#                       'btm3': 'ctx-rh-fusiform',
#                       'btm4': 'ctx-rh-inferiortemporal',
#                       'btm5': 'ctx-rh-inferiortemporal',
#                       'btm6': 'ctx-rh-inferiortemporal',
#                       'btp1': 'ctx-rh-lateraloccipital',
#                       'btp2': 'ctx-rh-fusiform',
#                       'btp3': 'ctx-rh-fusiform',
#                       'btp4': 'ctx-rh-inferiortemporal',
#                       'btp5': 'ctx-rh-inferiortemporal',
#                       'btp6': 'ctx-rh-inferiortemporal',
#                       'c1': 'ctx-rh-superiorfrontal',
#                       'c10': 'ctx-rh-rostralmiddlefrontal',
#                       'c11': 'ctx-rh-rostralmiddlefrontal',
#                       'c12': 'ctx-rh-rostralmiddlefrontal',
#                       'c13': 'ctx-rh-rostralmiddlefrontal',
#                       'c14': 'ctx-rh-rostralmiddlefrontal',
#                       'c15': 'ctx-rh-caudalmiddlefrontal',
#                       'c16': 'ctx-rh-precentral',
#                       'c17': 'ctx-rh-rostralmiddlefrontal',
#                       'c18': 'ctx-rh-parstriangularis',
#                       'c19': 'ctx-rh-parstriangularis',
#                       'c2': 'ctx-rh-rostralmiddlefrontal',
#                       'c20': 'ctx-rh-parstriangularis',
#                       'c21': 'ctx-rh-parsopercularis',
#                       'c22': 'ctx-rh-parsopercularis',
#                       'c23': 'ctx-rh-precentral',
#                       'c24': 'ctx-rh-precentral',
#                       'c25': 'ctx-rh-parsorbitalis',
#                       'c26': 'ctx-rh-parsorbitalis',
#                       'c27': 'ctx-rh-parstriangularis',
#                       'c28': 'ctx-rh-parstriangularis',
#                       'c29': 'ctx-rh-parsopercularis',
#                       'c3': 'ctx-rh-rostralmiddlefrontal',
#                       'c30': 'ctx-rh-parsopercularis',
#                       'c31': 'ctx-rh-precentral',
#                       'c32': 'ctx-rh-postcentral',
#                       'c33': 'ctx-rh-superiortemporal',
#                       'c34': 'ctx-rh-superiortemporal',
#                       'c35': 'ctx-rh-insula',
#                       'c36': 'ctx-rh-insula',
#                       'c37': 'ctx-rh-supramarginal',
#                       'c38': 'ctx-rh-supramarginal',
#                       'c39': 'ctx-rh-supramarginal',
#                       'c4': 'ctx-rh-rostralmiddlefrontal',
#                       'c40': 'ctx-rh-postcentral',
#                       'c41': 'ctx-rh-superiortemporal',
#                       'c42': 'ctx-rh-superiortemporal',
#                       'c43': 'ctx-rh-superiortemporal',
#                       'c44': 'ctx-rh-transversetemporal',
#                       'c45': 'ctx-rh-superiortemporal',
#                       'c46': 'ctx-rh-supramarginal',
#                       'c47': 'ctx-rh-supramarginal',
#                       'c48': 'ctx-rh-supramarginal',
#                       'c49': 'ctx-rh-middletemporal',
#                       'c5': 'ctx-rh-rostralmiddlefrontal',
#                       'c50': 'ctx-rh-middletemporal',
#                       'c51': 'ctx-rh-superiortemporal',
#                       'c52': 'ctx-rh-superiortemporal',
#                       'c53': 'ctx-rh-superiortemporal',
#                       'c54': 'ctx-rh-superiortemporal',
#                       'c55': 'ctx-rh-supramarginal',
#                       'c56': 'ctx-rh-supramarginal',
#                       'c57': 'ctx-rh-inferiortemporal',
#                       'c58': 'ctx-rh-middletemporal',
#                       'c59': 'ctx-rh-middletemporal',
#                       'c6': 'ctx-rh-rostralmiddlefrontal',
#                       'c60': 'ctx-rh-superiortemporal',
#                       'c61': 'ctx-rh-superiortemporal',
#                       'c62': 'ctx-rh-superiortemporal',
#                       'c63': 'ctx-rh-superiortemporal',
#                       'c64': 'ctx-rh-bankssts',
#                       'c65': 'ctx-rh-inferiorparietal',
#                       'c7': 'ctx-rh-caudalmiddlefrontal',
#                       'c8': 'ctx-rh-caudalmiddlefrontal',
#                       'c9': 'ctx-rh-rostralmiddlefrontal'},
#  'ch_lobe_mapping': {'btm1': 'R_Temporal_lobe',
#                      'btm2': 'R_Temporal_lobe',
#                      'btm3': 'R_Temporal_lobe',
#                      'btm4': 'R_Temporal_lobe',
#                      'btm5': 'R_Temporal_lobe',
#                      'btm6': 'R_Temporal_lobe',
#                      'btp1': 'R_Occipital_lobe',
#                      'btp2': 'R_Temporal_lobe',
#                      'btp3': 'R_Temporal_lobe',
#                      'btp4': 'R_Temporal_lobe',
#                      'btp5': 'R_Temporal_lobe',
#                      'btp6': 'R_Temporal_lobe',
#                      'c1': 'R_Frontal_lobe',
#                      'c10': 'R_Frontal_lobe',
#                      'c11': 'R_Frontal_lobe',
#                      'c12': 'R_Frontal_lobe',
#                      'c13': 'R_Frontal_lobe',
#                      'c14': 'R_Frontal_lobe',
#                      'c15': 'R_Frontal_lobe',
#                      'c16': 'R_Frontal_lobe',
#                      'c17': 'R_Frontal_lobe',
#                      'c18': 'R_Frontal_lobe',
#                      'c19': 'R_Frontal_lobe',
#                      'c2': 'R_Frontal_lobe',
#                      'c20': 'R_Frontal_lobe',
#                      'c21': 'R_Frontal_lobe',
#                      'c22': 'R_Frontal_lobe',
#                      'c23': 'R_Frontal_lobe',
#                      'c24': 'R_Frontal_lobe',
#                      'c25': 'R_Frontal_lobe',
#                      'c26': 'R_Frontal_lobe',
#                      'c27': 'R_Frontal_lobe',
#                      'c28': 'R_Frontal_lobe',
#                      'c29': 'R_Frontal_lobe',
#                      'c3': 'R_Frontal_lobe',
#                      'c30': 'R_Frontal_lobe',
#                      'c31': 'R_Frontal_lobe',
#                      'c32': 'R_Parietal_lobe',
#                      'c33': 'R_Temporal_lobe',
#                      'c34': 'R_Temporal_lobe',
#                      'c35': 'Unknown',
#                      'c36': 'Unknown',
#                      'c37': 'R_Parietal_lobe',
#                      'c38': 'R_Parietal_lobe',
#                      'c39': 'R_Parietal_lobe',
#                      'c4': 'R_Frontal_lobe',
#                      'c40': 'R_Parietal_lobe',
#                      'c41': 'R_Temporal_lobe',
#                      'c42': 'R_Temporal_lobe',
#                      'c43': 'R_Temporal_lobe',
#                      'c44': 'R_Temporal_lobe',
#                      'c45': 'R_Temporal_lobe',
#                      'c46': 'R_Parietal_lobe',
#                      'c47': 'R_Parietal_lobe',
#                      'c48': 'R_Parietal_lobe',
#                      'c49': 'R_Temporal_lobe',
#                      'c5': 'R_Frontal_lobe',
#                      'c50': 'R_Temporal_lobe',
#                      'c51': 'R_Temporal_lobe',
#                      'c52': 'R_Temporal_lobe',
#                      'c53': 'R_Temporal_lobe',
#                      'c54': 'R_Temporal_lobe',
#                      'c55': 'R_Parietal_lobe',
#                      'c56': 'R_Parietal_lobe',
#                      'c57': 'R_Temporal_lobe',
#                      'c58': 'R_Temporal_lobe',
#                      'c59': 'R_Temporal_lobe',
#                      'c6': 'R_Frontal_lobe',
#                      'c60': 'R_Temporal_lobe',
#                      'c61': 'R_Temporal_lobe',
#                      'c62': 'R_Temporal_lobe',
#                      'c63': 'R_Temporal_lobe',
#                      'c64': 'R_Temporal_lobe',
#                      'c65': 'R_Parietal_lobe',
#                      'c7': 'R_Frontal_lobe',
#                      'c8': 'R_Frontal_lobe',
#                      'c9': 'R_Frontal_lobe'},
#  'chanlabels': ['c1',
#                 'c2',
#                 'c3',
#                 'c4',
#                 'c5',
#                 'c6',
#                 'c7',
#                 'c8',
#                 'c9',
#                 'c10',
#                 'c11',
#                 'c12',
#                 'c13',
#                 'c14',
#                 'c15',
#                 'c16',
#                 'c17',
#                 'c18',
#                 'c19',
#                 'c20',
#                 'c21',
#                 'c22',
#                 'c23',
#                 'c24',
#                 'c25',
#                 'c26',
#                 'c27',
#                 'c28',
#                 'c29',
#                 'c30',
#                 'c31',
#                 'c32',
#                 'c33',
#                 'c34',
#                 'c35',
#                 'c36',
#                 'c37',
#                 'c38',
#                 'c39',
#                 'c40',
#                 'c41',
#                 'c42',
#                 'c43',
#                 'c44',
#                 'c45',
#                 'c46',
#                 'c47',
#                 'c48',
#                 'c49',
#                 'c50',
#                 'c51',
#                 'c52',
#                 'c53',
#                 'c54',
#                 'c55',
#                 'c56',
#                 'c57',
#                 'c58',
#                 'c59',
#                 'c60',
#                 'c61',
#                 'c62',
#                 'c63',
#                 'c64',
#                 'btm1',
#                 'btm2',
#                 'btm3',
#                 'btm4',
#                 'btm5',
#                 'btm6',
#                 'btp1',
#                 'btp2',
#                 'btp3',
#                 'btp4',
#                 'btp5',
#                 'btp6'],
#  'channeltypes': {'btm1': 'strip',
#                   'btm2': 'strip',
#                   'btm3': 'strip',
#                   'btm4': 'strip',
#                   'btm5': 'strip',
#                   'btm6': 'strip',
#                   'btp1': 'strip',
#                   'btp2': 'strip',
#                   'btp3': 'strip',
#                   'btp4': 'strip',
#                   'btp5': 'strip',
#                   'btp6': 'strip',
#                   'c1': 'eeg',
#                   'c10': 'eeg',
#                   'c100': 'eeg',
#                   'c101': 'eeg',
#                   'c102': 'eeg',
#                   'c103': 'eeg',
#                   'c104': 'eeg',
#                   'c105': 'eeg',
#                   'c106': 'eeg',
#                   'c107': 'eeg',
#                   'c108': 'eeg',
#                   'c109': 'eeg',
#                   'c11': 'eeg',
#                   'c110': 'eeg',
#                   'c111': 'eeg',
#                   'c112': 'eeg',
#                   'c113': 'eeg',
#                   'c114': 'eeg',
#                   'c115': 'eeg',
#                   'c116': 'eeg',
#                   'c117': 'eeg',
#                   'c118': 'eeg',
#                   'c119': 'eeg',
#                   'c12': 'eeg',
#                   'c120': 'eeg',
#                   'c121': 'eeg',
#                   'c122': 'eeg',
#                   'c123': 'eeg',
#                   'c124': 'eeg',
#                   'c125': 'eeg',
#                   'c126': 'eeg',
#                   'c127': 'eeg',
#                   'c13': 'eeg',
#                   'c14': 'eeg',
#                   'c15': 'eeg',
#                   'c16': 'eeg',
#                   'c17': 'eeg',
#                   'c18': 'eeg',
#                   'c19': 'eeg',
#                   'c2': 'eeg',
#                   'c20': 'eeg',
#                   'c21': 'eeg',
#                   'c22': 'eeg',
#                   'c23': 'eeg',
#                   'c24': 'eeg',
#                   'c25': 'eeg',
#                   'c26': 'eeg',
#                   'c27': 'eeg',
#                   'c28': 'eeg',
#                   'c29': 'eeg',
#                   'c3': 'eeg',
#                   'c30': 'eeg',
#                   'c31': 'eeg',
#                   'c32': 'eeg',
#                   'c33': 'eeg',
#                   'c34': 'eeg',
#                   'c35': 'eeg',
#                   'c36': 'eeg',
#                   'c37': 'eeg',
#                   'c38': 'eeg',
#                   'c39': 'eeg',
#                   'c4': 'eeg',
#                   'c40': 'eeg',
#                   'c41': 'eeg',
#                   'c42': 'eeg',
#                   'c43': 'eeg',
#                   'c44': 'eeg',
#                   'c45': 'eeg',
#                   'c46': 'eeg',
#                   'c47': 'eeg',
#                   'c48': 'eeg',
#                   'c49': 'eeg',
#                   'c5': 'eeg',
#                   'c50': 'eeg',
#                   'c51': 'eeg',
#                   'c52': 'eeg',
#                   'c53': 'eeg',
#                   'c54': 'eeg',
#                   'c55': 'eeg',
#                   'c56': 'eeg',
#                   'c57': 'eeg',
#                   'c58': 'eeg',
#                   'c59': 'eeg',
#                   'c6': 'eeg',
#                   'c60': 'eeg',
#                   'c61': 'eeg',
#                   'c62': 'eeg',
#                   'c63': 'eeg',
#                   'c64': 'eeg',
#                   'c7': 'eeg',
#                   'c77': 'eeg',
#                   'c78': 'eeg',
#                   'c79': 'eeg',
#                   'c8': 'eeg',
#                   'c80': 'eeg',
#                   'c81': 'eeg',
#                   'c82': 'eeg',
#                   'c83': 'eeg',
#                   'c84': 'eeg',
#                   'c85': 'eeg',
#                   'c86': 'eeg',
#                   'c87': 'eeg',
#                   'c88': 'eeg',
#                   'c89': 'eeg',
#                   'c9': 'eeg',
#                   'c90': 'eeg',
#                   'c91': 'eeg',
#                   'c92': 'eeg',
#                   'c93': 'eeg',
#                   'c96': 'eeg',
#                   'c98': 'eeg',
#                   'c99': 'eeg',
#                   'ekgl': 'bad-non',
#                   'ekgr': 'bad-non',
#                   'event': 'bad-non',
#                   'lm': 'bad-non',
#                   'sti014': 'seeg'},
#  'clinical_center': 'umf',
#  'clinical_difficulty': 1,
#  'clinical_match': nan,
#  'clinical_semiology': [],
#  'dataset_id': 'sz',
#  'date_of_recording': 1521364567,
#  'edffilename': 'SEIZURE.edf',
#  'engel_score': 1,
#  'equipment': '',
#  'events': [],
#  'ez_elecs': [],
#  'ez_hypo_brainregion': 'r anterior temporal lobe',
#  'ez_hypo_contacts': [],
#  'filename': 'umf001_sz_raw.fif',
#  'gender': 'f',
#  'hand_dominant': nan,
#  'highpass_freq': 0.0,
#  'length_of_recording': 192066,
#  'linefreq': 60,
#  'lowpass_freq': 499.7060546875,
#  'modality': 'ieeg',
#  'non_eeg_channels': ['ekgl', 'ekgr', 'sti014'],
#  'note': '',
#  'number_chans': 129,
#  'numwins': 1535,
#  'offsetind': None,
#  'offsetsec': None,
#  'offsetwin': None,
#  'onset': None,
#  'onset_age': nan,
#  'onsetind': None,
#  'onsetsec': None,
#  'onsetwin': None,
#  'outcome': 's',
#  'patient_id': 'umf001',
#  'perturbtype': 'C',
#  'radius': 1.5,
#  'reference': 'monopolar',
#  'resect_elecs': [],
#  'resected_contacts': [],
#  'resultfilename': 'umf001_sz_fragmodel.npz',
#  'samplepoints': [[0, 249],
#                   [125, 374],
#                   [250, 499],
#                   [375, 624],
#                   [500, 749],
#                   [625, 874],
#                   [750, 999],
#                   [875, 1124],
#                   [1000, 1249],
#                   [1125, 1374],
#                   [1250, 1499],
#                   [1375, 1624],
#                   [1500, 1749],
#                   [1625, 1874],
#                   [1750, 1999],
#                   [1875, 2124],
#                   [2000, 2249],
#                   [2125, 2374],
#                   [2250, 2499],
#                   [2375, 2624],
#                   [2500, 2749],
#                   [2625, 2874],
#                   [2750, 2999],
#                   [2875, 3124],
#                   [3000, 3249],
#                   [3125, 3374],
#                   [3250, 3499],
#                   [3375, 3624],
#                   [3500, 3749],
#                   [3625, 3874],
#                   [3750, 3999],
#                   [3875, 4124],
#                   [4000, 4249],
#                   [4125, 4374],
#                   [4250, 4499],
#                   [4375, 4624],
#                   [4500, 4749],
#                   [4625, 4874],
#                   [4750, 4999],
#                   [4875, 5124],
#                   [5000, 5249],
#                   [5125, 5374],
#                   [5250, 5499],
#                   [5375, 5624],
#                   [5500, 5749],
#                   [5625, 5874],
#                   [5750, 5999],
#                   [5875, 6124],
#                   [6000, 6249],
#                   [6125, 6374],
#                   [6250, 6499],
#                   [6375, 6624],
#                   [6500, 6749],
#                   [6625, 6874],
#                   [6750, 6999],
#                   [6875, 7124],
#                   [7000, 7249],
#                   [7125, 7374],
#                   [7250, 7499],
#                   [7375, 7624],
#                   [7500, 7749],
#                   [7625, 7874],
#                   [7750, 7999],
#                   [7875, 8124],
#                   [8000, 8249],
#                   [8125, 8374],
#                   [8250, 8499],
#                   [8375, 8624],
#                   [8500, 8749],
#                   [8625, 8874],
#                   [8750, 8999],
#                   [8875, 9124],
#                   [9000, 9249],
#                   [9125, 9374],
#                   [9250, 9499],
#                   [9375, 9624],
#                   [9500, 9749],
#                   [9625, 9874],
#                   [9750, 9999],
#                   [9875, 10124],
#                   [10000, 10249],
#                   [10125, 10374],
#                   [10250, 10499],
#                   [10375, 10624],
#                   [10500, 10749],
#                   [10625, 10874],
#                   [10750, 10999],
#                   [10875, 11124],
#                   [11000, 11249],
#                   [11125, 11374],
#                   [11250, 11499],
#                   [11375, 11624],
#                   [11500, 11749],
#                   [11625, 11874],
#                   [11750, 11999],
#                   [11875, 12124],
#                   [12000, 12249],
#                   [12125, 12374],
#                   [12250, 12499],
#                   [12375, 12624],
#                   [12500, 12749],
#                   [12625, 12874],
#                   [12750, 12999],
#                   [12875, 13124],
#                   [187000, 187249],
#                   [187125, 187374],
#                   [187250, 187499],
#                   [187375, 187624],
#                   [187500, 187749],
#                   [187625, 187874],
#                   [187750, 187999],
#                   [187875, 188124],
#                   [188000, 188249],
#                   [188125, 188374],
#                   [188250, 188499],
#                   [188375, 188624],
#                   [188500, 188749],
#                   [188625, 188874],
#                   [188750, 188999],
#                   [188875, 189124],
#                   [189000, 189249],
#                   [189125, 189374],
#                   [189250, 189499],
#                   [189375, 189624],
#                   [189500, 189749],
#                   [189625, 189874],
#                   [189750, 189999],
#                   [189875, 190124],
#                   [190000, 190249],
#                   [190125, 190374],
#                   [190250, 190499],
#                   [190375, 190624],
#                   [190500, 190749],
#                   [190625, 190874],
#                   [190750, 190999],
#                   [190875, 191124],
#                   [191000, 191249],
#                   [191125, 191374],
#                   [191250, 191499],
#                   [191375, 191624],
#                   [191500, 191749],
#                   [191625, 191874],
#                   [191750, 191999]],
#  'samplerate': 999.412109375,
#  'seizure_semiology': [],
#  'stabilizeflag': False,
#  'stepsize': 125,
#  'termination': None,
#  'type': 'sz',
#  'winsize': 250}

# %% [markdown]
# # Convert Non-ImgPipe Localized Contacts To Similar Format
#
# 1. Convert to .mat file dictionary style and save into elecs/
# 2. read in .mat file
# 3. add onto metadata

# %%
reference = 'monopolar'
modality = 'ieeg'
center = 'umg'
patid = 'umf004'
datasetid = 'sz'

atlasname = 'dk'

results_dir = f"/Users/adam2392/Downloads/output_new/fragility/{reference}/{modality}/{center}"
outputmetafilepath = os.path.join(results_dir, f"{patid}_{datasetid}_frag.json")

atlasmapfile = "../../data/mrtrix3_labelconvert/fs2lobes_cinginc_convert.txt"
atlaslabelfile = "../../data/mrtrix3_labelconvert/fs2lobes_cinginc_labels.txt"

fsdir = "/Users/adam2392/Dropbox/phd_research/data/neuroimaging_results/freesurfer_output/"
origchlabelfile = os.path.join(fsdir, f"outputfiles/{patid}/coregistration/{patid}_elec_f.mat")
chlabelfile = os.path.join(fsdir, f"{patid}/elecs/{patid}_elecs_all_{atlasname}.mat")

t1_mgz_img = os.path.join(fsdir, patid, "mri", "T1.mgz")
t1_dest_img = os.path.join(fsdir, patid,"mri", "T1.nii")
ct_src_img = os.path.join(fsdir, patid,"CT", "CT.nii")
transform_mat_path = os.path.join(fsdir, patid,"CT", "fsl_ct-to-t1fs_omat.txt")
ct_in_t1_img = os.path.join(fsdir, patid,"CT", "rCT.nii.gz")

brainmask_path = os.path.join(fsdir, patid, "mri", "brainmask.mgz")

# %%
# read in original ch labels file
matreader = MatReader()
origchlabels = matreader.loadmat(origchlabelfile)
elecf = origchlabels['elecf']
print(origchlabels.keys())
print(elecf.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'elecf'])
# dict_keys(['unit', 'label', 'elecpos', 'chanpos', 'tra', 'cfg'])

# %%
# read in new ch labels file
matreader = MatReader()
chlabels = matreader.loadmat(chlabelfile)
elecmat_t1 = chlabels['elecmatrix']
elecanat = chlabels['anatomy']
eleclabels = chlabels['eleclabels']

eleclabels = np.array([x[0] for x in eleclabels])
elecanat = np.array([x[3] for x in elecanat])
# Out:
# [-30.7511104   24.45556607 -10.93617317]

# %%
eleclabels = np.array(elecf['label'])
elecmat = np.array(elecf['elecpos'])

print(eleclabels.shape, elecmat.shape)
# Out:
# (146,) (146, 3)

# %%
os.listdir("/Users/adam2392/Dropbox/phd_research/data/neuroimaging_results/freesurfer_output/la03/CT/")
# Out:
# ['CT.nii']

# %%
# convert mgz to nifti images
# convert_mgz_to_nifti(t1_mgz_img, t1_dest_img)

# run fsl coregistration CT->T1 nifti
map_ct_to_t1(ct_src_img, t1_dest_img, ct_in_t1_img, transform_mat_path)

# %%
import subprocess
from ast import literal_eval

def convert_mgz_to_nifti(src_img, dest_img):
    cp = subprocess.run("mrconvert %s %s --force;" \
                            % (src_img, dest_img),
                        shell=True, stdout=subprocess.PIPE)
    return cp
    
def map_ct_to_t1(ct_src_img, t1_dest_img, ct_in_t1_img, transformat_mat_path):
    fsl_str_cmd = f"flirt -in {ct_src_img} \
                            -ref {t1_dest_img} \
                            -omat {transformat_mat_path} \
                            -out {ct_in_t1_img}"
    print(fsl_str_cmd)
    cp = subprocess.run(fsl_str_cmd, shell=True, stdout=subprocess.PIPE)
    
    
    return cp
    
def transform_ct_to_t1(ctcoords, t1_dest_img, ct_src_img, transform_mat):
    coords_str = " ".join([str(x) for x in ctcoords])
    
    cp = subprocess.run("%s | img2imgcoord -mm -src %s -dest %s -xfm %s" \
                            % (coords_str, ct_src_img, t1_dest_img, transform_mat),
                        shell=True, stdout=subprocess.PIPE)
    transformed_coords_str = cp.args.strip().split("|")[0]
    return np.array([float(x) for x in transformed_coords_str.split(" ") if x])

from nibabel.affines import apply_affine

def filter_electrodes_outbrain(elec_coords_mm, brainmask_img):
    brainmask_data = brainmask_img.get_fdata()
    brainmask_affine = brainmask_img.affine
    inv_affine = np.linalg.inv(brainmask_affine)

    # Convert contact xyz coordinates to CT voxels
    elec_coords_CTvox = {}
    for label, contact in elec_coords_mm.items():
        elec_coords_CTvox[label] = apply_affine(inv_affine, contact)

    # Filter out electrodes not within brain mask
    elec_in_brain = {}
    for label, contact in elec_coords_CTvox.items():
        if brainmask_data[int(contact[0]), int(contact[1]), int(contact[2])] != 0:
            elec_in_brain[label] = contact
    return elec_in_brain

# %%
# transform ct to t1
elecmat_t1 = []
for elecxyz in elecmat:
    elecmat_t1.append(transform_ct_to_t1(elecxyz, t1_dest_img, ct_src_img, transform_mat_path))
elecmat_t1 = np.array(elecmat_t1)
print(elecmat_t1.shape)
print(eleclabels.shape)
# Out:
# (66, 3)
# (66,)

# %%
elecdict = {}
for i, chlabel in enumerate(eleclabels):
    elecdict[chlabel] = elecmat_t1[i]

# %%
brainmask_img = nb.load(brainmask_path)
in_contacts = filter_electrodes_outbrain(elecdict, brainmask_img)
out_contacts = [ch for ch in eleclabels if ch not in in_contacts]
print(in_contacts.keys())
print(len(in_contacts))
# Out:
# dict_keys(['ltp1', 'ltp2', 'ltp3', 'la1', 'la2', 'la3', 'la4', 'la5', 'la6', 'lofs1', 'lofs2', 'lofs3', 'lph1', 'lph2', 'lh1', 'lh2', 'lh3', 'lmcsm1', 'lmcsm2', 'ra1', 'ra2', 'ra3'])
# 22
